# %% [markdown]
# 파이썬 딥러닝 텐서플로 ch3.1 ~ 3 50p ~ 86p
#
# ---

# %% [markdown]
# # PART 03 케라스(Keras)

# %% [markdown]
# ## 01 딥러닝 준비

# %% [markdown]
# 케라스 API
# - 고수준의 딥러닝 라이브러리
# - GPU 연산을 수행하는 기능을 직접 수행하지 않고 텐서플로, CNTK, Theano, MXNet 등의 백엔드 엔진을 지정하여 사용한다는 차이점
#
# - 목적 : 딥러닝 라이브러리를 쉽고 간결한 코드로 실행할 수 있게 만들어주는 것
#   - 장점 : 직관적. 사용자 친화적 설계. 백엔드 엔진 쉽게 변경 가능.
#   - 한계점 : 복잡한 구조의 모델 구현과 사용자 정의 훈련을 위해서는 텐서플로의 저수준 API 활용해야한다

# %% [markdown]
# ### 1-1 주요 용어

# %% [markdown]
# #### 1-1-1 하이퍼파라미터
# 사용자가 직접 설정해야 하는 값들
# - 조절하는 행위 : 하이퍼파라미터 튜닝
# - 사용자가 별도로 설정해주지 않으면 기본값이 지정되어 있어 자동으로 적용

# %% [markdown]
# #### 1-1-2 과소적합 vs 과대적합
#
# - 예측할 데이터가 모델이 학습한 데이터와 다른 분포를 갖거나 / 학습한 데이터가 특정 레이블에 편향된 데이터로 이루어져 있다면 -> 모델이 학습한 후 예측 성능이 현저히 떨어지게 된다

# %% [markdown]
# #### 1-1-3 에포크(epoch)
#
# - 딥러닝 : 데이터셋을 학습하는 과정을 여러 번 반복(iteration)하면서 최적의 모델 가중치를 찾는 과정
#
# - 에포크 : 딥러닝 모델이 반복 훈련을 할 때 데이터셋을 전부 학습에 사용하는 1회의 훈련 루프
#
#  * 모델이 과소적합되었다 판단 -> epoch 늘려서 다시 학습
#  * 모델이 빠르게 과대적합 구간으로 진입 -> epoch 줄여서 최적 구간에서 학습을 조기에 종료하는 것

# %% [markdown]
# #### 1-1-4 손실함수
#
# 손실함수 : 예측 값과 정답 값의 차이 또는 오차
# - 사용자가 정의해야한다
#
#
# 분류
# - 이진 분류
#   - 손실함수 : `binary_crossentropy`
#   - 출력층의 활성화 함수 : `sigmoid`
# - 다중 분류
#   - 손실함수(정답 클래스가 원핫 벡터인 경우) : `categorical_crossentropy`
#   - 손실함수(정답 클래스가 레이블 값으로 표현) : `sparse_categorical_crossentropy`
#   - 출력층의 활성화 함수 : `softmax`
#
# 회귀 모델
# - 평균제곱오차(MSE), 평균절대값오차(MAE), 후버(Huber)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import tensorflow as tf

# 클래스
tf.keras.losses.BinaryCrossentropy()

# 함수
tf.keras.losses.binary_crossentropy
# Out:
# <function keras.src.losses.binary_crossentropy(y_true, y_pred, from_logits=False, label_smoothing=0.0, axis=-1)>

# %% [markdown]
# #### 1-1-5 경사하강법(gradient descent)
#
# - 딥러닝 모델을 훈련할 때, 모델 내부의 가중치에 대한 미분 값을 구하고 목적 함수 값이 낮아지는 방향으로 차감하면서 결국 최소 함수 값을 갖도록 하는 방법
#
# - 딥러닝 훈련 프로세스에서 경사하강법 알고리즘을 적용하여 손실함수 값을 최소로 만드는 가중치를 찾을 수 있다
#
# - 단순 선형회귀 수식 y = wx + b 주어졌을 때, 손실함수를 최소로 하는 w와 b를 구하는 과정을 경사하강법으로 구현

# %%
import numpy as np
import matplotlib.pyplot as plt

# 샘플에 활용할 데이터셋 만들기

def make_linear(w=0.5, b=0.8, size=50, noise=1.0):
  x = np.random.rand(size)
  y = w*x + b
  noise = np.random.uniform(-abs(noise), abs(noise), size = y.shape)
  yy = y+noise
  plt.figure(figsize=(10,7))
  plt.plot(x,y, color='r', label=f'y= {w}*x + {b}')
  plt.scatter(x, yy, label='data')
  plt.legend(fontsize=20)
  plt.show()
  print(f'w:{w}, b:{b}')
  return x, yy

x,y = make_linear(w=0.3, b=0.5, size=100, noise=0.01)
# Out:
# w:0.3, b:0.5

# %% [markdown]
# * w, b에 대한 그래디언트를 구하는 부분만 구현
#   + 그래디언트는 손실함수를 w,b에 대한 각각의 편미분 값을 구한 뒤 학습률 계수를 곱하여 이전의 w,b로부터 차감

# %%
# 최대 반복 횟수
num_epoch=1000

# 학습률
learning_rate=0.005

# 에러 기록
errors=[]

# random 한 값으로 w, b 초기화
w=np.random.uniform(low=0.0, high=1.0)
b=np.random.uniform(low=0.0, high=1.0)

for epoch in range(num_epoch):
  # 가설 정의
  y_hat=w*x+b

  # 손실 함수 정의
  error=0.5*((y_hat-y)**2).sum()
  if error<0.005:             # 오차가 0.005 이내로 수렴하면 반복문 종료
    break
  # 그라디언트 미분 계산      # 매 epoch마다 w,b에 대한 가중치 업데이트
  w=w-learning_rate*((y_hat-y)*x).sum()
  b=b-learning_rate*(y_hat-y).sum()

  errors.append(error)

  if epoch%5==0:
    print('{0:2}w={1:.5f}, b={2:.5f} error ={3:.5f}'.format(epoch, w, b, error))

print('----'*15)
print('{0:2}w={1:.1f}, b={2:.1f} error ={3:.5f}'.format(epoch, w, b, error))
# Out:
#  0w=0.43124, b=0.42771 error =0.08005
#  5w=0.41327, b=0.44048 error =0.05609
# 10w=0.39676, b=0.44926 error =0.04141
# 15w=0.38264, b=0.45674 error =0.03068
# 20w=0.37057, b=0.46314 error =0.02284
# 25w=0.36025, b=0.46862 error =0.01710
# 30w=0.35142, b=0.47329 error =0.01291
# 35w=0.34388, b=0.47729 error =0.00985
# 40w=0.33743, b=0.48071 error =0.00761
# 45w=0.33191, b=0.48364 error =0.00597
# ------------------------------------------------------------
# 49w=0.3, b=0.5 error =0.00499

# %%
plt.figure(figsize=(10,7))
plt.plot(errors)
plt.xlabel("epochs")
plt.ylabel('Error')
plt.show()

# %% [markdown]
# - 매번 실행할 때마다 수렴하는 속도는 차이가 있지만, 결국 목표하는 오차 범위 안으로 수렴해 반복문 종료. 설정했던 w,b 계수와 비슷한 값임.

# %% [markdown]
# ### 1-2 딥러닝 프로세스
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### 1-2-1 데이터 전처리
#
# : 데이터를 가공하는 단계
#
# * 배열의 차원을 변경하거나 스케일을 조정할 수 있다

# %% [markdown]
# #### 1-2-2 모델 생성
#
# : 모델의 구조를 정의하고 생성하는 단계
#
# * 순차적인 구조의 모델은 `Sequential API`
# * 다중 입력 및 출력을 가지고 복잡한 구조를 갖는 모델은 `Functional API` 혹은 `Model Subclassing`

# %% [markdown]
# #### 1-2-3 모델 컴파일
#
# : 생성된 모델 훈련에 사용할 손실함수(loss), 옵티마이저(optimizer), 평가지표(metrics) 등을 정의
#
# * 모델 인스턴스에 `compile()` 메소드 적용해 여러 가지 속성 값 설정

# %% [markdown]
# #### 1-2-4 모델 훈련
#
# : 모델을 훈련하는 단계
#
# - `fit()` 함수에 모델 훈련에 필요한 정보를 매개변수로 전달
#   - 훈련 데이터셋, 검증 데이터셋, epoch, 배치 크기 및 콜백 함수 등 지정

# %% [markdown]
# #### 1-2-5 모델 검증
#
# : 훈련이 완료된 모델을 검증하는 단계
#
# - 모델을 훈련할 때 사용하지 않은 검증 데이터셋을 모델에 입력하고 모델의 예측 값을 정답과 비교하여 평가지표 계산
# - 검증 결과를 바탕으로 다시 수정, 재평가하는 단계 통해 목표 성능에 도달할 때까지 과정 계속 반복

# %% [markdown]
# #### 1-2-6 모델 예측
#
# : 테스트셋에 대하여 모델이 예측하고 그 결과 반환

# %% [markdown]
# ## 02. 단순 신경망 훈련

# %% [markdown]
# ### 2-1 선형회귀
#
# 텐서플로 케라스를 활용하여 단순선형회귀 모델 직접 만들고 딥러닝 학습
#
# * y = wx + b
#   + w : 가중치(weight)
#   + b : 편향(bias)

# %% [markdown]
# ### 2-2 뉴런
#
# 뉴런(= 노드) : 인공 신경망 모델을 구성하는 하나의 신경.
#
# * 신경망은 여러 개의 레이어(layer)를 가지며 1개의 레이어는 1개 이상의 뉴런으로 구성
# * 뉴런의 내부에는 가중치가 존재하고 모델이 훈련을 진행하면서 오차 역전파를 통해 뉴런의 가중치 업데이트
#   + 역전파 : 손실함수를 미분한 결과인 그래디언트를 출력층에서 입력층 순으로 역으로 계산해 저장

# %% [markdown]
# ### 2-3 Dense 레이어
#
# Dense 레이어(= 완전 연결층(Fully Connected Layer)): 심층 신경망 모델을 구성하는 가장 기본 레이어.
#
# * Dense 레이어로 구성된 모델 - 각 레이어는 1개 이상의 뉴런으로 구성
#   + 노드의 개수를 Dense 레이어의 첫 번째 위치 인자로 지정
#   + activation 매개변수에 활성화 함수 지정하여 적용

# %%
import tensorflow as tf

# 10개의 노드로 이루어진 dense 레이어
tf.keras.layers.Dense(10)

# ReLU 활성화 함수 적용
tf.keras.layers.Dense(10, activation='relu')

# %% [markdown]
# ### 2-4 데이터셋 만들기

# %%
# 샘플 데이터셋 생성
x=np.arange(1,6)

#y=3x+2
y=3*x+2
print(x)
print(y)
# Out:
# [1 2 3 4 5]
# [ 5  8 11 14 17]

# %%
import matplotlib.pyplot as plt

# 시각화
plt.plot(x, y)
plt.title('y=3x+2')
plt.show()

# %% [markdown]
# ### 2-5 Sequential API
#
# Sequential API : 층을 이어 붙이듯 시퀀스에 맞게 일렬로 연결하는 방식.
#
# * 입력 레이어부터 출력 레이어까지 순서를 갖는다
# * 2개 이상의 다중 입력이나 다중 출력을 갖는 복잡한 구조를 만들 수 없다
# * 쌓고자 하는 레이어의 개수는 제한이 없다

# %% [markdown]
# #### 2-5-1 모델 구조
#
# 1. 파이썬 리스트 형태로 여러 개의 층을 입력

# %%
import tensorflow as tf

#리스트형
model=tf.keras.Sequential([
    tf.keras.layers.Dense(10),
    tf.keras.layers.Dense(5),
    tf.keras.layers.Dense(1)
])

# %% [markdown]
# 2. add 함수로 레이어 추가로 Sequential 클래스 객체 만든 후, 층을 추가

# %%
#add 함수로 레이어 추가
model=tf.keras.Sequential()
model.add(tf.keras.layers.Dense(10))
model.add(tf.keras.layers.Dense(5))
model.add(tf.keras.layers.Dense(1))

# %% [markdown]
# #### 2-5-2 입력 데이터 형태
#
# * 반드시 첫 번째 층은 `input_shape`매개변수 지정해야 한다
#   + 주입할 데이터셋의 shape을 투플 혹은 리스트로 지정
#   + shape에서 각 행은 샘플 데이터. 열은 입력 변수(-> input_shape)
#   - (4,) 또는 [4]로 지정

# %%
import tensorflow as tf
model=tf.keras.Sequential([
    # 입력 데이터의 shape=(150, 4)인 경우 input_shape 지정
    tf.keras.layers.Dense(10, input_shape=[4]),
    tf.keras.layers.Dense(5),
    tf.keras.layers.Dense(1)
])

# %% [markdown]
# #### 2-5-3 단순선형회귀 모델 정의
#
# 단순선형회귀 모델을 만들기 위해서 1개의 뉴런을 가지는 Dense 레이어 한 개 사용. 여기서 1개의 뉴런은 w, b를 매개변수로 갖는다
#
# * Dense 레이어는 use_bias=True가 기본 설정되어 상수항 b가 추가된다
# - x 값을 나타내는 입력 변수 1개만 존재 -> input_shape=[1]로 지정

# %%
# 단순선형회귀 모델 생성
model=tf.keras.Sequential([
    tf.keras.layers.Dense(1, input_shape=[1])
])

# %% [markdown]
# ### 2-6 모델 요약
#
# 모델 요약 확인 => `model.summary()`
#
# * 모델의 구조 확인 가능. 층별 노드의 개수 표기. 훈련 시 업데이트할 파라미터의 개수 표기
#   + Total params : 모델 내부에 존재하는 모든 파라미터의 합계
#   + Trainable params : 모델 훈련 시 업데이트할 파라미터의 총 개수
#   + Non-trainable params : 훈련 시 업데이트하지 않을 파라미터의 총 개수
#
# * 단순선형회귀 모델에서는 업데이트 파라미터가 가중치 w와 편향 b 두개

# %%
# 모델 요약
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_11 (Dense)            (None, 1)                 2
#
# =================================================================
# Total params: 2 (8.00 Byte)
# Trainable params: 2 (8.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### 2-7 컴파일
#
# 컴파일 단계에서는 모델의 훈련 과정에서 적용할 옵티마이저, 손실함수, 그리고 평가지표 등을 정의
#
#  -> 클래스 인스턴스, 함수 혹은 사전 정의된 문자열 3가지 방법으로 지정 가능

# %%
# 긴 문자열 지정
model.compile(optimizer='sgd', loss='mean_squared_error', metrics=['mean_squared_error', 'mean_absolute_error'])

# %%
# 짧은 문자열 지정
model.compile(optimizer='sgd', loss='mse', metrics=['mse', 'mae'])

# %%
# 클래스 인스턴스 지정
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.005),
              loss=tf.keras.losses.MeanAbsoluteError(),
              metrics=[tf.keras.metrics.MeanAbsoluteError(),
                       tf.keras.metrics.MeanSquaredError()])

# %%
# 컴파일
model.compile(optimizer='sgd', loss='mse', metrics=['mae'])     # sgd는 확률적 경사하강법(Stochastic Gradient Descent)

# %% [markdown]
# ### 2-8 훈련
#
# 모델이 훈련한다 = 가중치 텐서를 업데이트하는 과정
#
# * fit() 메소드에 훈련용 데이터셋의 입력(x)와 정답에 해당하는 출력(y), 반복 훈련할 epoch 수 지정
#   + 매 epoch 끝날 때마다 훈련 데이터셋에 대한 손실과 평가지표 출력
#   + verbose = 0 옵션 지정 시 훈련 중간 과정 출력x
#   + 검증 데이터셋(validation_data) 옵션 지정 시 검증셋에 대한 손실과 평가지표도 함께 출력

# %%
# 훈련
model.fit(x, y, epochs=5)
# Out:
# Epoch 1/5
# 1/1 [==============================] - 1s 1s/step - loss: 54.8629 - mae: 7.0189
# Epoch 2/5
# 1/1 [==============================] - 0s 12ms/step - loss: 32.1236 - mae: 5.4144
# Epoch 3/5
# 1/1 [==============================] - 0s 12ms/step - loss: 18.8712 - mae: 4.1893
# Epoch 4/5
# 1/1 [==============================] - 0s 12ms/step - loss: 11.1473 - mae: 3.2539
# Epoch 5/5
# 1/1 [==============================] - 0s 11ms/step - loss: 6.6452 - mae: 2.5397

# %% [markdown]
# - 모델의 예측 오차 점점 줄어드는 것. 모델이 잘 학습되고 있음
#
# - 하지만 반복 훈련 횟수 충분하지 않아 학습이 덜 되었다 -> 과소적합 상태

# %%
# 단순 선형회귀 모델 생성
model=tf.keras.Sequential([
    tf.keras.layers.Dense(1, input_shape=[1])
])

# 컴파일
model.compile(optimizer='sgd', loss='mse', metrics=['mae'])

# 훈련
history=model.fit(x, y, epochs=1200)
# Out:
# Epoch 1/1200
# 1/1 [==============================] - 1s 593ms/step - loss: 259.9294 - mae: 14.9264
# Epoch 2/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 151.5159 - mae: 11.4241
# Epoch 3/1200
# 1/1 [==============================] - 0s 14ms/step - loss: 88.3376 - mae: 8.7504
# Epoch 4/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 51.5201 - mae: 6.7092
# Epoch 5/1200
# 1/1 [==============================] - 0s 16ms/step - loss: 30.0645 - mae: 5.1509
# Epoch 6/1200
# 1/1 [==============================] - 0s 14ms/step - loss: 17.5609 - mae: 3.9612
# Epoch 7/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 10.2741 - mae: 3.0530
# Epoch 8/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 6.0275 - mae: 2.3595
# Epoch 9/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 3.5525 - mae: 1.8301
# Epoch 10/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 2.1099 - mae: 1.4258
# Epoch 11/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.2690 - mae: 1.1171
# Epoch 12/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.7787 - mae: 0.8813
# Epoch 13/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4927 - mae: 0.7012
# Epoch 14/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3258 - mae: 0.5637
# Epoch 15/1200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2282 - mae: 0.4585
# Epoch 16/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1711 - mae: 0.3782
# Epoch 17/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1376 - mae: 0.3168
# Epoch 18/1200
# 1/1 [==============================] - 0s 23ms/step - loss: 0.1178 - mae: 0.2819
# Epoch 19/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1060 - mae: 0.2685
# Epoch 20/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0989 - mae: 0.2580
# Epoch 21/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0945 - mae: 0.2499
# Epoch 22/1200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0917 - mae: 0.2470
# Epoch 23/1200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0898 - mae: 0.2481
# Epoch 24/1200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0884 - mae: 0.2488
# Epoch 25/1200
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0874 - mae: 0.2491
# Epoch 26/1200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0866 - mae: 0.2492
# Epoch 27/1200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0858 - mae: 0.2490
# Epoch 28/1200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0852 - mae: 0.2487
# Epoch 29/1200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0846 - mae: 0.2482
# Epoch 30/1200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0840 - mae: 0.2477
# Epoch 31/1200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0834 - mae: 0.2471
# Epoch 32/1200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0828 - mae: 0.2464
# Epoch 33/1200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0822 - mae: 0.2457
# Epoch 34/1200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0817 - mae: 0.2450
# Epoch 35/1200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0811 - mae: 0.2442
# Epoch 36/1200
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0806 - mae: 0.2434
# Epoch 37/1200
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0800 - mae: 0.2427
# Epoch 38/1200
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0795 - mae: 0.2419
# Epoch 39/1200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0790 - mae: 0.2411
# Epoch 40/1200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0784 - mae: 0.2403
# Epoch 41/1200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0779 - mae: 0.2395
# Epoch 42/1200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0774 - mae: 0.2387
# Epoch 43/1200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0768 - mae: 0.2379
# Epoch 44/1200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0763 - mae: 0.2371
# Epoch 45/1200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0758 - mae: 0.2363
# Epoch 46/1200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0753 - mae: 0.2355
# Epoch 47/1200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0748 - mae: 0.2347
# Epoch 48/1200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0743 - mae: 0.2339
# Epoch 49/1200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0738 - mae: 0.2331
# Epoch 50/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0733 - mae: 0.2324
# Epoch 51/1200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0728 - mae: 0.2316
# Epoch 52/1200
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0723 - mae: 0.2308
# Epoch 53/1200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0718 - mae: 0.2300
# Epoch 54/1200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0713 - mae: 0.2292
# Epoch 55/1200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0708 - mae: 0.2285
# Epoch 56/1200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0704 - mae: 0.2277
# Epoch 57/1200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0699 - mae: 0.2269
# Epoch 58/1200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0694 - mae: 0.2261
# Epoch 59/1200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0689 - mae: 0.2254
# Epoch 60/1200
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0685 - mae: 0.2246
# Epoch 61/1200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0680 - mae: 0.2239
# Epoch 62/1200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0676 - mae: 0.2231
# Epoch 63/1200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0671 - mae: 0.2223
# Epoch 64/1200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0667 - mae: 0.2216
# Epoch 65/1200
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0662 - mae: 0.2208
# Epoch 66/1200
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0658 - mae: 0.2201
# Epoch 67/1200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0653 - mae: 0.2194
# Epoch 68/1200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0649 - mae: 0.2186
# Epoch 69/1200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0644 - mae: 0.2179
# Epoch 70/1200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0640 - mae: 0.2171
# Epoch 71/1200
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0636 - mae: 0.2164
# Epoch 72/1200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0631 - mae: 0.2157
# Epoch 73/1200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0627 - mae: 0.2149
# Epoch 74/1200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0623 - mae: 0.2142
# Epoch 75/1200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0619 - mae: 0.2135
# Epoch 76/1200
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0615 - mae: 0.2128
# Epoch 77/1200
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0610 - mae: 0.2121
# Epoch 78/1200
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0606 - mae: 0.2113
# Epoch 79/1200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0602 - mae: 0.2106
# Epoch 80/1200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0598 - mae: 0.2099
# Epoch 81/1200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0594 - mae: 0.2092
# Epoch 82/1200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0590 - mae: 0.2085
# Epoch 83/1200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0586 - mae: 0.2078
# Epoch 84/1200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0582 - mae: 0.2071
# Epoch 85/1200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0578 - mae: 0.2064
# Epoch 86/1200
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0574 - mae: 0.2057
# Epoch 87/1200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0570 - mae: 0.2050
# Epoch 88/1200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0567 - mae: 0.2043
# Epoch 89/1200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0563 - mae: 0.2036
# Epoch 90/1200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0559 - mae: 0.2029
# Epoch 91/1200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0555 - mae: 0.2022
# Epoch 92/1200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0551 - mae: 0.2015
# Epoch 93/1200
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0548 - mae: 0.2009
# Epoch 94/1200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0544 - mae: 0.2002
# Epoch 95/1200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0540 - mae: 0.1995
# Epoch 96/1200
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0537 - mae: 0.1988
# Epoch 97/1200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0533 - mae: 0.1982
# Epoch 98/1200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0529 - mae: 0.1975
# Epoch 99/1200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0526 - mae: 0.1968
# Epoch 100/1200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0522 - mae: 0.1962
# Epoch 101/1200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0519 - mae: 0.1955
# Epoch 102/1200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0515 - mae: 0.1948
# Epoch 103/1200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0512 - mae: 0.1942
# Epoch 104/1200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0508 - mae: 0.1935
# Epoch 105/1200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0505 - mae: 0.1929
# Epoch 106/1200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0502 - mae: 0.1922
# Epoch 107/1200
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0498 - mae: 0.1916
# Epoch 108/1200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0495 - mae: 0.1909
# Epoch 109/1200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0491 - mae: 0.1903
# Epoch 110/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0488 - mae: 0.1896
# Epoch 111/1200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0485 - mae: 0.1890
# Epoch 112/1200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0482 - mae: 0.1883
# Epoch 113/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0478 - mae: 0.1877
# Epoch 114/1200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0475 - mae: 0.1871
# Epoch 115/1200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0472 - mae: 0.1864
# Epoch 116/1200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0469 - mae: 0.1858
# Epoch 117/1200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0465 - mae: 0.1852
# Epoch 118/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0462 - mae: 0.1846
# Epoch 119/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0459 - mae: 0.1839
# Epoch 120/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0456 - mae: 0.1833
# Epoch 121/1200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0453 - mae: 0.1827
# Epoch 122/1200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0450 - mae: 0.1821
# Epoch 123/1200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0447 - mae: 0.1815
# Epoch 124/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0444 - mae: 0.1808
# Epoch 125/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0441 - mae: 0.1802
# Epoch 126/1200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0438 - mae: 0.1796
# Epoch 127/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0435 - mae: 0.1790
# Epoch 128/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0432 - mae: 0.1784
# Epoch 129/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0429 - mae: 0.1778
# Epoch 130/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0426 - mae: 0.1772
# Epoch 131/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0423 - mae: 0.1766
# Epoch 132/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0421 - mae: 0.1760
# Epoch 133/1200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0418 - mae: 0.1754
# Epoch 134/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0415 - mae: 0.1748
# Epoch 135/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0412 - mae: 0.1742
# Epoch 136/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0409 - mae: 0.1736
# Epoch 137/1200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0407 - mae: 0.1731
# Epoch 138/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0404 - mae: 0.1725
# Epoch 139/1200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0401 - mae: 0.1719
# Epoch 140/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0398 - mae: 0.1713
# Epoch 141/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0396 - mae: 0.1707
# Epoch 142/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0393 - mae: 0.1702
# Epoch 143/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0390 - mae: 0.1696
# Epoch 144/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0388 - mae: 0.1690
# Epoch 145/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0385 - mae: 0.1684
# Epoch 146/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0382 - mae: 0.1679
# Epoch 147/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0380 - mae: 0.1673
# Epoch 148/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0377 - mae: 0.1667
# Epoch 149/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0375 - mae: 0.1662
# Epoch 150/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0372 - mae: 0.1656
# Epoch 151/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0370 - mae: 0.1650
# Epoch 152/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0367 - mae: 0.1645
# Epoch 153/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0365 - mae: 0.1639
# Epoch 154/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0362 - mae: 0.1634
# Epoch 155/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0360 - mae: 0.1628
# Epoch 156/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0357 - mae: 0.1623
# Epoch 157/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0355 - mae: 0.1617
# Epoch 158/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0353 - mae: 0.1612
# Epoch 159/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0350 - mae: 0.1606
# Epoch 160/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0348 - mae: 0.1601
# Epoch 161/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0346 - mae: 0.1595
# Epoch 162/1200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0343 - mae: 0.1590
# Epoch 163/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0341 - mae: 0.1585
# Epoch 164/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0339 - mae: 0.1579
# Epoch 165/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0336 - mae: 0.1574
# Epoch 166/1200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0334 - mae: 0.1569
# Epoch 167/1200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0332 - mae: 0.1563
# Epoch 168/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0330 - mae: 0.1558
# Epoch 169/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0327 - mae: 0.1553
# Epoch 170/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0325 - mae: 0.1548
# Epoch 171/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0323 - mae: 0.1542
# Epoch 172/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0321 - mae: 0.1537
# Epoch 173/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0319 - mae: 0.1532
# Epoch 174/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0316 - mae: 0.1527
# Epoch 175/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0314 - mae: 0.1522
# Epoch 176/1200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0312 - mae: 0.1516
# Epoch 177/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0310 - mae: 0.1511
# Epoch 178/1200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0308 - mae: 0.1506
# Epoch 179/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0306 - mae: 0.1501
# Epoch 180/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0304 - mae: 0.1496
# Epoch 181/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0302 - mae: 0.1491
# Epoch 182/1200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0300 - mae: 0.1486
# Epoch 183/1200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0298 - mae: 0.1481
# Epoch 184/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0296 - mae: 0.1476
# Epoch 185/1200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0294 - mae: 0.1471
# Epoch 186/1200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0292 - mae: 0.1466
# Epoch 187/1200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0290 - mae: 0.1461
# Epoch 188/1200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0288 - mae: 0.1456
# Epoch 189/1200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0286 - mae: 0.1451
# Epoch 190/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0284 - mae: 0.1446
# Epoch 191/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0282 - mae: 0.1441
# Epoch 192/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0280 - mae: 0.1436
# Epoch 193/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0278 - mae: 0.1432
# Epoch 194/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0276 - mae: 0.1427
# Epoch 195/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0274 - mae: 0.1422
# Epoch 196/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0273 - mae: 0.1417
# Epoch 197/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0271 - mae: 0.1412
# Epoch 198/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0269 - mae: 0.1408
# Epoch 199/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0267 - mae: 0.1403
# Epoch 200/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0265 - mae: 0.1398
# Epoch 201/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0264 - mae: 0.1393
# Epoch 202/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0262 - mae: 0.1389
# Epoch 203/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0260 - mae: 0.1384
# Epoch 204/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0258 - mae: 0.1379
# Epoch 205/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0256 - mae: 0.1375
# Epoch 206/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0255 - mae: 0.1370
# Epoch 207/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0253 - mae: 0.1365
# Epoch 208/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0251 - mae: 0.1361
# Epoch 209/1200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0250 - mae: 0.1356
# Epoch 210/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0248 - mae: 0.1352
# Epoch 211/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0246 - mae: 0.1347
# Epoch 212/1200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0245 - mae: 0.1342
# Epoch 213/1200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0243 - mae: 0.1338
# Epoch 214/1200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0241 - mae: 0.1333
# Epoch 215/1200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0240 - mae: 0.1329
# Epoch 216/1200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0238 - mae: 0.1324
# Epoch 217/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0236 - mae: 0.1320
# Epoch 218/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0235 - mae: 0.1315
# Epoch 219/1200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0233 - mae: 0.1311
# Epoch 220/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0232 - mae: 0.1307
# Epoch 221/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0230 - mae: 0.1302
# Epoch 222/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0229 - mae: 0.1298
# Epoch 223/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0227 - mae: 0.1293
# Epoch 224/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0226 - mae: 0.1289
# Epoch 225/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0224 - mae: 0.1285
# Epoch 226/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0222 - mae: 0.1280
# Epoch 227/1200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0221 - mae: 0.1276
# Epoch 228/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0219 - mae: 0.1272
# Epoch 229/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0218 - mae: 0.1267
# Epoch 230/1200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0217 - mae: 0.1263
# Epoch 231/1200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0215 - mae: 0.1259
# Epoch 232/1200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0214 - mae: 0.1254
# Epoch 233/1200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0212 - mae: 0.1250
# Epoch 234/1200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0211 - mae: 0.1246
# Epoch 235/1200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0209 - mae: 0.1242
# Epoch 236/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0208 - mae: 0.1238
# Epoch 237/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0207 - mae: 0.1233
# Epoch 238/1200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0205 - mae: 0.1229
# Epoch 239/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0204 - mae: 0.1225
# Epoch 240/1200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0202 - mae: 0.1221
# Epoch 241/1200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0201 - mae: 0.1217
# Epoch 242/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0200 - mae: 0.1213
# Epoch 243/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0198 - mae: 0.1209
# Epoch 244/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0197 - mae: 0.1205
# Epoch 245/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0196 - mae: 0.1200
# Epoch 246/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0194 - mae: 0.1196
# Epoch 247/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0193 - mae: 0.1192
# Epoch 248/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0192 - mae: 0.1188
# Epoch 249/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0190 - mae: 0.1184
# Epoch 250/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0189 - mae: 0.1180
# Epoch 251/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0188 - mae: 0.1176
# Epoch 252/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0187 - mae: 0.1172
# Epoch 253/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0185 - mae: 0.1168
# Epoch 254/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0184 - mae: 0.1164
# Epoch 255/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0183 - mae: 0.1160
# Epoch 256/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0182 - mae: 0.1157
# Epoch 257/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0180 - mae: 0.1153
# Epoch 258/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0179 - mae: 0.1149
# Epoch 259/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0178 - mae: 0.1145
# Epoch 260/1200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0177 - mae: 0.1141
# Epoch 261/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0176 - mae: 0.1137
# Epoch 262/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0174 - mae: 0.1133
# Epoch 263/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0173 - mae: 0.1129
# Epoch 264/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0172 - mae: 0.1126
# Epoch 265/1200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0171 - mae: 0.1122
# Epoch 266/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0170 - mae: 0.1118
# Epoch 267/1200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0169 - mae: 0.1114
# Epoch 268/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0167 - mae: 0.1110
# Epoch 269/1200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0166 - mae: 0.1107
# Epoch 270/1200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0165 - mae: 0.1103
# Epoch 271/1200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0164 - mae: 0.1099
# Epoch 272/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0163 - mae: 0.1096
# Epoch 273/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0162 - mae: 0.1092
# Epoch 274/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0161 - mae: 0.1088
# Epoch 275/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0160 - mae: 0.1084
# Epoch 276/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0159 - mae: 0.1081
# Epoch 277/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0157 - mae: 0.1077
# Epoch 278/1200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0156 - mae: 0.1074
# Epoch 279/1200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0155 - mae: 0.1070
# Epoch 280/1200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0154 - mae: 0.1066
# Epoch 281/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0153 - mae: 0.1063
# Epoch 282/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0152 - mae: 0.1059
# Epoch 283/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0151 - mae: 0.1055
# Epoch 284/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0150 - mae: 0.1052
# Epoch 285/1200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0149 - mae: 0.1048
# Epoch 286/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0148 - mae: 0.1045
# Epoch 287/1200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0147 - mae: 0.1041
# Epoch 288/1200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0146 - mae: 0.1038
# Epoch 289/1200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0145 - mae: 0.1034
# Epoch 290/1200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0144 - mae: 0.1031
# Epoch 291/1200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0143 - mae: 0.1027
# Epoch 292/1200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0142 - mae: 0.1024
# Epoch 293/1200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0141 - mae: 0.1020
# Epoch 294/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0140 - mae: 0.1017
# Epoch 295/1200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0139 - mae: 0.1013
# Epoch 296/1200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0138 - mae: 0.1010
# Epoch 297/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0138 - mae: 0.1007
# Epoch 298/1200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0137 - mae: 0.1003
# Epoch 299/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0136 - mae: 0.1000
# Epoch 300/1200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0135 - mae: 0.0996
# Epoch 301/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0134 - mae: 0.0993
# Epoch 302/1200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0133 - mae: 0.0990
# Epoch 303/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0132 - mae: 0.0986
# Epoch 304/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0131 - mae: 0.0983
# Epoch 305/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0130 - mae: 0.0980
# Epoch 306/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0129 - mae: 0.0976
# Epoch 307/1200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0129 - mae: 0.0973
# Epoch 308/1200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0128 - mae: 0.0970
# Epoch 309/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.
1200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0081 - mae: 0.0770
# Epoch 377/1200
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0080 - mae: 0.0768
# Epoch 378/1200
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0079 - mae: 0.0765
# Epoch 379/1200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0079 - mae: 0.0763
# Epoch 380/1200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0078 - mae: 0.0760
# Epoch 381/1200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0078 - mae: 0.0757
# Epoch 382/1200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0077 - mae: 0.0755
# Epoch 383/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0077 - mae: 0.0752
# Epoch 384/1200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0076 - mae: 0.0750
# Epoch 385/1200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0076 - mae: 0.0747
# Epoch 386/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0075 - mae: 0.0745
# Epoch 387/1200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0075 - mae: 0.0742
# Epoch 388/1200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0074 - mae: 0.0740
# Epoch 389/1200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0074 - mae: 0.0737
# Epoch 390/1200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0073 - mae: 0.0735
# Epoch 391/1200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0073 - mae: 0.0732
# Epoch 392/1200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0072 - mae: 0.0730
# Epoch 393/1200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0072 - mae: 0.0727
# Epoch 394/1200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0071 - mae: 0.0725
# Epoch 395/1200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0071 - mae: 0.0722
# Epoch 396/1200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0070 - mae: 0.0720
# Epoch 397/1200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0070 - mae: 0.0717
# Epoch 398/1200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0069 - mae: 0.0715
# Epoch 399/1200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0069 - mae: 0.0713
# Epoch 400/1200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0068 - mae: 0.0710
# Epoch 401/1200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0068 - mae: 0.0708
# Epoch 402/1200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0068 - mae: 0.0705
# Epoch 403/1200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0067 - mae: 0.0703
# Epoch 404/1200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0067 - mae: 0.0701
# Epoch 405/1200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0066 - mae: 0.0698
# Epoch 406/1200
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0066 - mae: 0.0696
# Epoch 407/1200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0065 - mae: 0.0694
# Epoch 408/1200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0065 - mae: 0.0691
# Epoch 409/1200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0064 - mae: 0.0689
# Epoch 410/1200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0064 - mae: 0.0687
# Epoch 411/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0064 - mae: 0.0684
# Epoch 412/1200
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0063 - mae: 0.0682
# Epoch 413/1200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0063 - mae: 0.0680
# Epoch 414/1200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0062 - mae: 0.0677
# Epoch 415/1200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0062 - mae: 0.0675
# Epoch 416/1200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0061 - mae: 0.0673
# Epoch 417/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0061 - mae: 0.0670
# Epoch 418/1200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0061 - mae: 0.0668
# Epoch 419/1200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0060 - mae: 0.0666
# Epoch 420/1200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0060 - mae: 0.0664
# Epoch 421/1200
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0059 - mae: 0.0661
# Epoch 422/1200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0059 - mae: 0.0659
# Epoch 423/1200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0059 - mae: 0.0657
# Epoch 424/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0058 - mae: 0.0655
# Epoch 425/1200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0058 - mae: 0.0653
# Epoch 426/1200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0057 - mae: 0.0650
# Epoch 427/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0057 - mae: 0.0648
# Epoch 428/1200
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0057 - mae: 0.0646
# Epoch 429/1200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0056 - mae: 0.0644
# Epoch 430/1200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0056 - mae: 0.0642
# Epoch 431/1200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0055 - mae: 0.0639
# Epoch 432/1200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0055 - mae: 0.0637
# Epoch 433/1200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0055 - mae: 0.0635
# Epoch 434/1200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0054 - mae: 0.0633
# Epoch 435/1200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0054 - mae: 0.0631
# Epoch 436/1200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0054 - mae: 0.0629
# Epoch 437/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0053 - mae: 0.0627
# Epoch 438/1200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0053 - mae: 0.0624
# Epoch 439/1200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0053 - mae: 0.0622
# Epoch 440/1200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0052 - mae: 0.0620
# Epoch 441/1200
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0052 - mae: 0.0618
# Epoch 442/1200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0052 - mae: 0.0616
# Epoch 443/1200
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0051 - mae: 0.0614
# Epoch 444/1200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.
1200
# 1/1 [==============================] - 0s 11ms/step - loss: 3.9793e-05 - mae: 0.0054
# Epoch 1161/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 3.9526e-05 - mae: 0.0054
# Epoch 1162/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 3.9259e-05 - mae: 0.0054
# Epoch 1163/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 3.8993e-05 - mae: 0.0054
# Epoch 1164/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 3.8727e-05 - mae: 0.0053
# Epoch 1165/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 3.8469e-05 - mae: 0.0053
# Epoch 1166/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 3.8210e-05 - mae: 0.0053
# Epoch 1167/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 3.7951e-05 - mae: 0.0053
# Epoch 1168/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 3.7695e-05 - mae: 0.0053
# Epoch 1169/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 3.7443e-05 - mae: 0.0053
# Epoch 1170/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 3.7189e-05 - mae: 0.0052
# Epoch 1171/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 3.6937e-05 - mae: 0.0052
# Epoch 1172/1200
# 1/1 [==============================] - 0s 16ms/step - loss: 3.6690e-05 - mae: 0.0052
# Epoch 1173/1200
# 1/1 [==============================] - 0s 19ms/step - loss: 3.6442e-05 - mae: 0.0052
# Epoch 1174/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 3.6196e-05 - mae: 0.0052
# Epoch 1175/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 3.5949e-05 - mae: 0.0051
# Epoch 1176/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 3.5708e-05 - mae: 0.0051
# Epoch 1177/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 3.5464e-05 - mae: 0.0051
# Epoch 1178/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 3.5223e-05 - mae: 0.0051
# Epoch 1179/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 3.4988e-05 - mae: 0.0051
# Epoch 1180/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 3.4752e-05 - mae: 0.0051
# Epoch 1181/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 3.4519e-05 - mae: 0.0050
# Epoch 1182/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 3.4285e-05 - mae: 0.0050
# Epoch 1183/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 3.4054e-05 - mae: 0.0050
# Epoch 1184/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 3.3822e-05 - mae: 0.0050
# Epoch 1185/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 3.3597e-05 - mae: 0.0050
# Epoch 1186/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 3.3366e-05 - mae: 0.0050
# Epoch 1187/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 3.3141e-05 - mae: 0.0049
# Epoch 1188/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 3.2918e-05 - mae: 0.0049
# Epoch 1189/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 3.2697e-05 - mae: 0.0049
# Epoch 1190/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 3.2479e-05 - mae: 0.0049
# Epoch 1191/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 3.2257e-05 - mae: 0.0049
# Epoch 1192/1200
# 1/1 [==============================] - 0s 18ms/step - loss: 3.2037e-05 - mae: 0.0049
# Epoch 1193/1200
# 1/1 [==============================] - 0s 13ms/step - loss: 3.1821e-05 - mae: 0.0048
# Epoch 1194/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 3.1607e-05 - mae: 0.0048
# Epoch 1195/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 3.1394e-05 - mae: 0.0048
# Epoch 1196/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 3.1184e-05 - mae: 0.0048
# Epoch 1197/1200
# 1/1 [==============================] - 0s 11ms/step - loss: 3.0970e-05 - mae: 0.0048
# Epoch 1198/1200
# 1/1 [==============================] - 0s 10ms/step - loss: 3.0765e-05 - mae: 0.0048
# Epoch 1199/1200
# 1/1 [==============================] - 0s 9ms/step - loss: 3.0558e-05 - mae: 0.0047
# Epoch 1200/1200
# 1/1 [==============================] - 0s 12ms/step - loss: 3.0350e-05 - mae: 0.0047

# %% [markdown]
# - 충분한 epoch 동안 훈련한 후 mse, mae 모두 개선

# %%
import matplotlib.pyplot as plt

# 20 epoch까지 loss 수렴에 대한 시각화
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['mae'], label='mae')
plt.xlim(-1, 20)
plt.title('loss')
plt.legend()
plt.show()

# %% [markdown]
# - 모델 훈련 초기 단계에는 학습이 매우 빠른 속도로 진행되다가 일정 epoch 이후에는 학습 속도가 느려지는 패턴 보임

# %% [markdown]
# ### 2-9 검증
#
# 모델 인스턴스의 `evaluate()` 메소드로 모델의 성능 검증
#
# * 일반적으로 사전에 별도의 검증 데이터셋 준비하여 모델 성능 평가 -> 교차 검증
#   + 교차 검증 방법에는 홀드아웃(Hold-out), K-Fold 교차 검증 등

# %%
# 검증
model.evaluate(x, y)
# Out:
# 1/1 [==============================] - 0s 193ms/step - loss: 3.0145e-05 - mae: 0.0047
# [3.014479261764791e-05, 0.004712581634521484]

# %% [markdown]
# - loss와 mse 출력

# %% [markdown]
# ### 2-10 예측
#
# 훈련 완료된 모델 인스턴스의 `predict()` 메소드에 새로운 입력 데이터 넣어 주면 모델의 예측 값 얻을 수 있다

# %%
# 예측
model.predict([10])
# Out:
# 1/1 [==============================] - 0s 194ms/step
# array([[32.022774]], dtype=float32)

# %% [markdown]
# ## 03. 심층 신경망으로 이미지 분류
#
#
#
#
# 이미지 분류를 위해 단층이 아닌 더 깊은 층을 쌓아 깊이가 있는 딥러닝 모델 생성

# %% [markdown]
# ### 3-1 케라스 내장 데이터셋 로드
#
# * 케라스는 샘플 데이터셋 제공 tensorflow.keras.datasets
#   + boston_housing : 보스톤 주택 가격 데이터셋(회귀)
#   + cifar10 : CIFAR10 이미지 분류 데이터셋(분류)
#   + cifar100 : CIFAR100 이미지 분류 데이터셋(분류)
#   + mnist : mnist 손글씨 데이터셋(분류)
#   + fashion_mnist : 의류 데이터셋(분류)
#   + imdb : IMDb 영화 데이터셋(분류)
#   + reuters : Reuters 뉴스 토픽(분류)
#
# * 데이터 불러오기 위해 load_data() 메소드 사용
#   + 훈련 데이터셋과 검증 데이터셋 구분하여 제공

# %%
import tensorflow as tf

# 케라스 내장 데이터셋에서 mnist 데이터셋 로드
mnist=tf.keras.datasets.mnist

# %%
# load data()로 데이터셋 로드
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step

# %%
print("train set: ", x_train.shape, y_train.shape)
print("test set: ", x_test.shape, y_test.shape)
# Out:
# train set:  (60000, 28, 28) (60000,)
# test set:  (10000, 28, 28) (10000,)

# %% [markdown]
# - 훈련 셋에는 60000개의 데이터. 검증 셋에는 10000개 데이터 저장되어 있다
#
# - shape의 첫 번째는 데이터셋의 크기, 나머지는 순서대로 이미지의 세로, 가로의 픽셀 크기

# %%
# 데이터 시각화
import matplotlib.pyplot as plt

# canvas 생성
fig, axes=plt.subplots(3,5)
fig.set_size_inches(8,5)

for i in range(15):
  ax=axes[i//5, i%5]
  # imshow로 이미지 시각화
  ax.imshow(x_train[i], cmap='gray')
  ax.axis('off')
  ax.set_title(str(y_train[i]))

plt.tight_layout()
plt.show()

# %% [markdown]
# * mnist 데이터셋 : 사람의 필기체로 쓰인 0~9까지의 숫자들로 이루어진 데이터셋. 총 10개의 정답 레이블로 구성

# %% [markdown]
# ### 3-2 데이터 전처리
#
# 이미지 데이터에 대하여 정규화를 통해 데이터의 범위 조절

# %%
# x_train 배열의 데이터 확인
x_train[0, 10:15, 10:15] # 배열의 각 원소는 이미지를 구성하는 하나의 픽셀 값과 일대일 대칭
# Out:
# array([[  1, 154, 253,  90,   0],
#        [  0, 139, 253, 190,   2],
#        [  0,  11, 190, 253,  70],
#        [  0,   0,  35, 241, 225],
#        [  0,   0,   0,  81, 240]], dtype=uint8)

# %% [markdown]
# - 0~255 사이의 값. 데이터의 범위를 0 ~ 1로 정규화하기 위해 255로 나눈다

# %%
# 픽셀 값의 최소/최대값 확인
print(f"정규화 전] 최소값: {x_train.min()}, 최대값: {x_train.max()}") # 0~255

# 데이터 정규화
x_train = x_train/x_train.max()

# 정규화 후 최소/최대값 확인
print(f"정규화 후] 최소값: {x_train.min()}, 최대값: {x_train.max()}") # 0~1
# Out:
# 정규화 전] 최소값: 0, 최대값: 255
# 정규화 후] 최소값: 0.0, 최대값: 1.0

# %%
# test set에도 정규화 동일 적용
x_test = x_test / x_test.max()

# %%
# 변환 후 x_train 배열의 데이터 확인
x_train[0, 10:15, 10:15]
# Out:
# array([[0.00392157, 0.60392157, 0.99215686, 0.35294118, 0.        ],
#        [0.        , 0.54509804, 0.99215686, 0.74509804, 0.00784314],
#        [0.        , 0.04313725, 0.74509804, 0.99215686, 0.2745098 ],
#        [0.        , 0.        , 0.1372549 , 0.94509804, 0.88235294],
#        [0.        , 0.        , 0.        , 0.31764706, 0.94117647]])

# %% [markdown]
# - 정규화하는 이유 : 비정규화된 입력 데이터를 가질 때보다 더 빨리 수렴. 국소 최적에 빠지는 현상도 방지

# %% [markdown]
# ### 3-3 Flatten 레이어
#
# 정규화를 하더라도 개별 데이터 값의 범위는 축소되지만, 원본 배열의 형태는 그대로 유지된다
#
# * 2차원 입력은 Dense 레이어에 입력값으로 넣을 수 없다 -> 반드시 입력값으로 1차원 배열 들어가야 한다

# %%
print(f'변경 전 shape: {x_train.shape}')
print(f'1D로 shape 변경 후: {x_train.reshape(60000, -1).shape}')
# Out:
# 변경 전 shape: (60000, 28, 28)
# 1D로 shape 변경 후: (60000, 784)

# %% [markdown]
# * Flatten 레이어 사용하여 다차원 데이터를 1차원으로 펼치기

# %%
print(f'변경 전 shape: {x_train.shape}')

# Flatten 레이어 적용 후 shape 확인
print(f'Flatten 적용 후: {tf.keras.layers.Flatten()(x_train).shape}')
# Out:
# 변경 전 shape: (60000, 28, 28)
# Flatten 적용 후: (60000, 784)

# %% [markdown]
# ### 3-4 활성화 함수
#
# 활성화 함수
# - 입력을 비선형 출력으로 변환해주는 함수
# - 선형관계를 나타내는 함수에 비선형성을 추가하는 방법으로 표현
#  - 비선형을 추가하지 않고 선형 함수로만 층을 구성한다면 모델을 깊게 구성하더라도 결국은 선형함수로 표현된다.
#
# * 시그모이드(Sigmoid), 하이퍼볼릭 탄젠트(Hyperbolic Tangent 혹은 tanh), ReLU(Rectified Unit), Leaky ReLU 등
#
# * activation 매개변수에 활성화 함수 문자열 대입

# %%
# Dense 레이어에 relu 활성화 함수를 적용한 경우
tf.keras.layers.Dense(128, activation='relu')

# %% [markdown]
# - 별도의 층처럼 적용할 수도 - Dense 레이어 다음에 배치 정규화를 적용한 후 활성화 함수를 적용하고자 할 때 많이 사용

# %%
# Dense 레이어와 relu 활성화 함수 레이어를 별도 적용한 경우
model=tf.keras.Sequential([
    tf.keras.layers.Dense(128),
    tf.keras.layers.Activation('relu')
])

# %% [markdown]
# ### 3-5 입력과 출력
#
# * 딥러닝 모델 만들 때 입력 데이터의 형태를 나타내는 input_shape 매개변수 지정하는 것 일반적
#
# * 가장 마지막 레이어인 출력층의 노드 개수는 반드시 분류해야 할 클래스의 개수와 동일

# %%
model=tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    # 노드 = 10개(클래스 개수와 동일)
    tf.keras.layers.Dense(10, activation='softmax'),
])

# %% [markdown]
# 모델의 깊이(레이어의 개수)와 너비(각 레이어를 구성하는 노드의 개수)에 대한 정답은 없다 -> 여러 가지 시도를 통해서 최적의 모델 형태 찾을 필요가 있다
#
# - 다중 분류 문제에서는 `softmax` 활성화 함수 사용해야 한다
# - 이진 분류 모델에서는 `sigmoid` 활성화 함수 적용해야 한다
#   - 이진 분류 모델이더라도 출력 레이어의 클래스를 원핫 인코딩으로 변환하여 노드 개수가 2개인 경우에는 softmax 함수 사용

# %% [markdown]
# ### 3-6 손실함수
#
# 분류 모델의 손실함수는 모델의 출력층에 따라 설정

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * 이진 분류기 생성 시, 출력층의 노드 개수가 1 -> activation='sigmoid'. 손실함수는 'binary_crossentropy'

# %%
# 이진 분류 (출력 노드 개수 =1, sigmoid인 경우)
model.compile(loss='binary_crossentropy')

# %% [markdown]
# * 출력층의 노드 개수가 2개 이상인 경우 -> activation='softmax'. 손실함수는 'categorical_crossentropy' 혹은 'sparse_categorical_crossentropy'
#   + 출력 데이터(y)가 원핫 벡터인 경우 'categorical_crossentropy' 지정

# %%
# y가 원핫 벡터인 경우
# [0.. 0.. 0.. 1.. 0..]
model.compile(loss='categorical_crossentropy')
# y가 원핫 벡터가 아닌 경우 -> mnist의 경우
# [5]
model.compile(loss='sparse_categorical_crossentropy')

# %% [markdown]
# ### 3-7 옵티마이저
#
# 옵티마이저(optimizer) : 손실을 낮추기 위해서, 신경망의 가중치와 학습률와 같은 신경망의 속성을 변경하는 데 사용되는 최적화 방법
#
# * 일반적으로 많이 사용되는 알고리즘은 `Adam`
#
# * 케라스에서 지원하는 옵티마이저 목록
#   + SGD
#   + Adam
#   + Adagrad
#   + Nadam
#   + RMSprop
#   + Adadelta
#   + Adamax
#   + Ftrl
#
# * 옵티마이저는 클래스 인스턴스로 지정하거나 문자열로 지정 가능
#   + 문자열로 지정할 때는 클래스 이름을 소문자로 표기
#   + 클래스 인스턴스로 지정할 때는 하이퍼파라미터 직접 설정 가능

# %%
# 클래스 인스턴스로 지정
adam=tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=adam)

# 문자열로 지정
model.compile(optimizer=['adam'])

# %% [markdown]
# ### 3-8 평가지표
#
# 분류 모델에 대한 평가지표(metrics)는 정확도 'accuracy' 가장 많이 사용.
#
# * 'auc', 'precision', 'recall' 등의 지표도 많이 사용
# * 클래스 인스턴스로 지정하거나 문자열로 지정 가능

# %%
# 클래스 인스턴스로 지정
acc=tf.keras.metrics.SparseCategoricalAccuracy()

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=[acc])

# %%
# 문자열로 지정
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ### 3-9 훈련
#
# 모델을 훈련할 때 검증 셋을 추가 지정하면, 매 epoch마다 훈련 손실과 검증 손실, 각 셋에 대한 평가지표 나란히 출력
#
# -> validation_data 매개변수에 투플 형식의 검증 셋 지정해주면 된다

# %%
# 훈련
model.fit(x_train, y_train,
          # 검증 셋 지정
          validation_data=(x_test, y_test),
          epochs=10,
          )
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 19s 8ms/step - loss: 0.2258 - accuracy: 0.9323 - val_loss: 0.1291 - val_accuracy: 0.9606
# Epoch 2/10
# 1875/1875 [==============================] - 16s 8ms/step - loss: 0.0938 - accuracy: 0.9715 - val_loss: 0.0893 - val_accuracy: 0.9726
# Epoch 3/10
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.0639 - accuracy: 0.9798 - val_loss: 0.0735 - val_accuracy: 0.9763
# Epoch 4/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0495 - accuracy: 0.9840 - val_loss: 0.0811 - val_accuracy: 0.9764
# Epoch 5/10
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0400 - accuracy: 0.9875 - val_loss: 0.0783 - val_accuracy: 0.9744
# Epoch 6/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0346 - accuracy: 0.9890 - val_loss: 0.0988 - val_accuracy: 0.9737
# Epoch 7/10
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0274 - accuracy: 0.9911 - val_loss: 0.0833 - val_accuracy: 0.9771
# Epoch 8/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0234 - accuracy: 0.9924 - val_loss: 0.0850 - val_accuracy: 0.9767
# Epoch 9/10
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.0236 - accuracy: 0.9922 - val_loss: 0.0844 - val_accuracy: 0.9771
# Epoch 10/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0188 - accuracy: 0.9939 - val_loss: 0.0746 - val_accuracy: 0.9810

# %% [markdown]
# ### 3-10 평가
#
# 훈련이 종료된 뒤 `evaluate()` 메소드로 모델 성능 검증하고 평가 결과 확인. 검증 셋인 x_test, y_test 함수에 전달
#
# * evaluate() 메소드는 컴파일 단계에서 지정한 손실과 정확도 순서대로 반환

# %% [markdown]
# ### 3-11 예측
#
# `predict()` 메소드에 이미지 데이터 넣어주면 모델의 예측 결과 반환

# %%
# 예측
predictions = model.predict(x_test)   # 새로운 데이터셋 준비x
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %% [markdown]
# * predictions 변수에 모델이 예측한 분류 결과를 넘파이 배열 형태로 저장

# %%
# 예측 결과 출력
predictions[0]
# Out:
# array([1.8014863e-14, 6.7880201e-11, 3.2456506e-09, 3.3175637e-10,
#        5.2762881e-12, 1.7156902e-12, 5.2896863e-17, 9.9999994e-01,
#        4.4618480e-12, 7.7145295e-12], dtype=float32)

# %% [markdown]
# * softmax 활성화 함수 거친 출력 값은 개별 클래스에 대한 분류 확률값
#   + 가장 높은 확률값을 가진 클래스가 최종 예측된 클래스

# %%
import numpy as np

# 0번 index에 대한 예측 클래스 출력
print(np.argmax(predictions[0]))

# 첫 10개 index에 대한 예측 클래스 출력
print(np.argmax(predictions[:10], axis=1))
# Out:
# 7
# [7 2 1 0 4 1 4 9 5 9]

# %%
# 데이터 시각화
import matplotlib.pyplot as plt
def get_one_result(idx):
  img, y_true, y_pred, confidence=x_test[idx], y_test[idx], np.argmax(predictions[idx]), 100*np.max(predictions[idx])
  return img, y_true, y_pred, confidence

# canvas 생성
fig, axes=plt.subplots(3,5)
fig.set_size_inches(12, 10)
for i in range(15):
  ax=axes[i//5, i%5]
  img, y_true, y_pred, confidence=get_one_result(i)
  #imshow로 시각화
  ax.imshow(img, cmap='gray')
  ax.set_xticks([])
  ax.set_yticks([])
  ax.set_title(f'True: {y_true}')
  ax.set_xlabel(f'Prediction: {y_pred}\nConfidence: ({confidence:.2f} %)')
plt.tight_layout()
plt.show()
